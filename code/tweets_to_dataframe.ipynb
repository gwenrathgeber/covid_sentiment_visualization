# %% [markdown]
# # Tweets to dataframe

# %%
import pandas as pd
import numpy as np
from textblob import TextBlob 
import re 
from textblob.sentiments import NaiveBayesAnalyzer
import time

# %%
class TweetAnalyzer():
    """
    Functionality for analyzing and categorizing content from tweets.
    """

    def clean_tweet(self, tweet):
        return ' '.join(re.sub("(@[A-Za-z0-9]+)|([^0-9A-Za-z \t])|(\w+:\/\/\S+)", " ", tweet).split())

    def analyze_sentiment(self, tweet):
        return TextBlob(self.clean_tweet(tweet), analyzer=NaiveBayesAnalyzer())
        
    def tweets_to_data_frame(self, tweets):
        df = pd.DataFrame(data=[tweet['full_text'] for tweet in tweets], columns=['full_text'])
        df['id'] = np.array([tweet['id'] for tweet in tweets])
        df['date'] = np.array([tweet['created_at'] for tweet in tweets])
        df['city'] = [tweet['place']['full_name'] for tweet in tweets]
        df['country_code'] = [tweet['place']['country_code'] for tweet in tweets]
        df['country'] = [tweet['place']['country'] for tweet in tweets]
        df['coordinates'] = [tweet['coordinates']['coordinates'] for tweet in tweets]

        return df

# %%
all_tweets = []
with open('./data/tweet_ids/hydrated/tweets.jsonl', 'r') as json_file:
    json_list = list(json_file)

for json_str in json_list:
    try:
      result = json.loads(json_str)
      all_tweets.append(result)
    except:
        pass

# %%
all_tweets = [tweet for tweet in all_tweets if type(tweet['place']) == dict]

# %%
ta = TweetAnalyzer()
df = ta.tweets_to_data_frame(all_tweets)

# %%
df = df[df['country_code'] == 'US']

# %%
df['state'] = [city[-2:] for city in df['city']]
# Out:
# C:\Users\Craig\anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
valid_states = ['OH', 'CA', 'MA', 'FL', 'IL', 'MD', 'NC', 'NY', 'AZ',
       'LA', 'TX', 'UT', 'GA', 'NV', 'MI', 'NJ', 'IN', 'ME', 'KS', 'VA',
       'MN', 'TN', 'PA', 'SC', 'WI', 'NM', 'OR', 'MO', 'WA', 'DC',
       'AL', 'CT', 'ID', 'KY', 'MS', 'CO', 'OK', 'HI', 'AR', 'VT', 'RI',
       'NH', 'MT', 'DE', 'NE',  'SD', 'IA', 'ND', 'WV',  'AK',
        'WY']
len(valid_states)
# Out:
# 51

# %%
df = df[df['state'].isin(valid_states)]

# %%
df['full_text'][0]
# Out:
# '#statewaterheaters #getitin #corona #keepingpeoplesafe #plumber #pickeringtonohio new water heater swap out @ Pickerington, Ohio https://t.co/fMcPtH88m4'

# %%
ta.analyze_sentiment(df['full_text'][1]).sentiment
# Out:
# Sentiment(classification='neg', p_pos=0.29355729258623176, p_neg=0.7064427074137692)

# %%
a,b,c = ta.analyze_sentiment(df['full_text'][1]).sentiment

# %%
print(a,b,c)
# Out:
# neg 0.29355729258623176 0.7064427074137692

# %%
df.shape[0]/2
# Out:
# 32297.5

# %%
df = df.reset_index()

# %%
df.loc[0:32316,:].to_csv('./data/tweets/cleaned_tweets_first_half.csv',index=False)
df.loc[32317:,:].to_csv('./data/tweets/cleaned_tweets_second_half.csv',index=False)

# %%
df1 = pd.read_csv('./data/tweets/cleaned_tweets_first_half.csv')
df2 = pd.read_csv('./data/tweets/cleaned_tweets_second_half.csv')

# %%
df = pd.read_csv('./data/tweets/cleaned_tweets_second_half.csv')

s= time.time()
for i, tweet in enumerate(df['full_text']):
    analysis = ta.analyze_sentiment(tweet).sentiment
    df.loc[i,'classification'] = analysis[0]
    df.loc[i,'p_pos'] = analysis[1]
    df.loc[i,'p_neg'] = analysis[2]
    if i % 100 == 0:
        print(f'{i} of {df.shape[0]}, time elapsed: {(time.time() - s) / 60} minutes')
        df.to_csv('./data/tweets/analyzed_tweets_second_half.csv',index=False)
        
df.to_csv('./data/tweets/analyzed_tweets_second_half.csv',index=False)
# Out:
# 0 of 32278, time elapsed: 0.06798480351765951 minutes
# 100 of 32278, time elapsed: 7.538872714837392 minutes
# 200 of 32278, time elapsed: 15.742492512861888 minutes
# 300 of 32278, time elapsed: 27.578842163085938 minutes
# 400 of 32278, time elapsed: 38.30125726064046 minutes
# 500 of 32278, time elapsed: 50.40722532669703 minutes
# 600 of 32278, time elapsed: 63.411704977353416 minutes
# 700 of 32278, time elapsed: 76.50852807362874 minutes
# 800 of 32278, time elapsed: 91.61251735289892 minutes
# 900 of 32278, time elapsed: 104.46022142569224 minutes
# 1000 of 32278, time elapsed: 111.25717825094858 minutes
# 1100 of 32278, time elapsed: 118.08280838330587 minutes
# 1200 of 32278, time elapsed: 124.8664674282074 minutes
# 1300 of 32278, time elapsed: 131.6899699131648 minutes
# 1400 of 32278, time elapsed: 138.5281332095464 minutes
# 1500 of 32278, time elapsed: 145.31273971001306 minutes
# 1600 of 32278, time elapsed: 152.13685722351073 minutes
# 1700 of 32278, time elapsed: 158.9136512994766 minutes
# 1800 of 32278, time elapsed: 165.74056266148884 minutes
# 1900 of 32278, time elapsed: 172.52044845024744 minutes
# 2000 of 32278, time elapsed: 179.34636117219924 minutes
# 2100 of 32278, time elapsed: 186.17149264812468 minutes
# 2200 of 32278, time elapsed: 192.96033781369528 minutes
# 2300 of 32278, time elapsed: 199.7948442141215 minutes
# 2400 of 32278, time elapsed: 206.57110637029012 minutes
# 2500 of 32278, time elapsed: 213.40829786459605 minutes
# 2600 of 32278, time elapsed: 220.1878013451894 minutes
# 2700 of 32278, time elapsed: 227.01532642443973 minutes
# 2800 of 32278, time elapsed: 233.83771523634593 minutes
# 2900 of 32278, time elapsed: 240.6167200366656 minutes
# 3000 of 32278, time elapsed: 247.4481180826823 minutes
# 3100 of 32278, time elapsed: 254.63389321962993 minutes
# 3200 of 32278, time elapsed: 262.13824110825857 minutes
# 3300 of 32278, time elapsed: 269.59609764814377 minutes
# 3400 of 32278, time elapsed: 277.0157716751099 minutes
# 3500 of 32278, time elapsed: 284.49389329353966 minutes
# 3600 of 32278, time elapsed: 292.08386673132577 minutes
# 3700 of 32278, time elapsed: 299.5275110721588 minutes
# 3800 of 32278, time elapsed: 306.9718031922976 minutes
# 3900 of 32278, time elapsed: 314.4375508069992 minutes
# 4000 of 32278, time elapsed: 321.87966566085817 minutes
# 4100 of 32278, time elapsed: 329.2806900978088 minutes
# 29500 of 32278, time elapsed: 2134.5054225722947 minutes
# 29600 of 32278, time elapsed: 2141.251318466663 minutes
# 29700 of 32278, time elapsed: 2147.9617732803026 minutes
# 29800 of 32278, time elapsed: 2154.7009014089904 minutes
# 29900 of 32278, time elapsed: 2161.411905090014 minutes
# 30000 of 32278, time elapsed: 2168.2205836375556 minutes
# 30100 of 32278, time elapsed: 2175.0515328645706 minutes
# 30200 of 32278, time elapsed: 2181.8325490077336 minutes
# 30300 of 32278, time elapsed: 2188.6327471256254 minutes
# 30400 of 32278, time elapsed: 2195.394830417633 minutes
# 30500 of 32278, time elapsed: 2202.2001981218655 minutes
# 30600 of 32278, time elapsed: 2209.0114501317344 minutes
# 30700 of 32278, time elapsed: 2215.759770317872 minutes
# 30800 of 32278, time elapsed: 2222.5008282780645 minutes
# 30900 of 32278, time elapsed: 2229.2021904349326 minutes
# 31000 of 32278, time elapsed: 2236.014060238997 minutes
# 31100 of 32278, time elapsed: 2242.824114902814 minutes
# 31200 of 32278, time elapsed: 2249.592880908648 minutes
# 31300 of 32278, time elapsed: 2256.406875371933 minutes
# 31400 of 32278, time elapsed: 2263.1813755075136 minutes
# 31500 of 32278, time elapsed: 2269.9912812431653 minutes
# 31600 of 32278, time elapsed: 2276.7613432367643 minutes
# 31700 of 32278, time elapsed: 2283.582252240181 minutes
# 31800 of 32278, time elapsed: 2290.4085642457007 minutes
# 31900 of 32278, time elapsed: 2297.1852088133496 minutes
# 32000 of 32278, time elapsed: 2303.9972752491635 minutes
# 32100 of 32278, time elapsed: 2310.7662065267564 minutes
# 32200 of 32278, time elapsed: 2317.5798520445824 minutes

# %%
df.head()
# Out:
#    index                                          full_text  \
# 0  79321  While admitted to St. Francis Hospital between...
# 1  79325  GOOD MORNING 😀 THANK YOU LORD FOR WAKING ME UP...
# 2  79326  🗣🗣HAPPY BELATED BDAY TO Terra Renee Matthews!!...
# 3  79331  Just posted a video @ Corona, California https...
# 4  79335  News roundup: more covid tracing apps released...
#
#                     id                            date          city  \
# 0  1268957415929757697  Fri Jun 05 17:26:38 +0000 2020   Chicago, IL
# 1  1268958726611927048  Fri Jun 05 17:31:51 +0000 2020  Whittier, CA
# 2  1268959375248568335  Fri Jun 05 17:34:25 +0000 2020  Berkeley, MO
# 3  1268960496746729472  Fri Jun 05 17:38:53 +0000 2020    Corona, CA
# 4  1268962295587016704  Fri Jun 05 17:46:02 +0000 2020   Chicago, IL
#
#   country_code        country                  coordinates state  \
# 0           US  United States              [-87.67, 42.01]    IL
# 1           US  United States       [-118.03407, 33.97542]    CA
# 2           US  United States  [-90.33590071, 38.74932691]    MO
# 3           US  United States          [-117.566, 33.8753]    CA
# 4           US  United States  [-87.60509849, 41.89186335]    IL
#
#   classification     p_pos     p_neg
# 0            pos  0.840656  0.159344
# 1            pos  0.988976  0.011024
# 2            pos  0.603010  0.396990
# 3            pos  0.731935  0.268065
# 4            pos  0.800698  0.199302

# %%
df = pd.read_csv('./data/tweets/analyzed_tweets_first_half.csv')
df_2 = pd.read_csv('./data/tweets/analyzed_tweets_second_half.csv')

# %%
df.drop(columns='index').head()
# Out:
#                                            full_text            id  \
# 0  #statewaterheaters #getitin #corona #keepingpe...  1.240728e+18
# 1  "ain't no humans outside! (corona!)" 😂😂😂🤣 @ Cl...  1.240728e+18
# 2  current weather in Corona: moderate rain, 56°F...  1.240729e+18
# 3  Quarantine 🏓 training ! Adding some kicks 💥. \...  1.240729e+18
# 4  #quarantine #stockpiling #food #sexylatino #la...  1.240731e+18
#
#                              date              city country_code  \
# 0  Thu Mar 19 19:53:17 +0000 2020  Pickerington, OH           US
# 1  Thu Mar 19 19:53:46 +0000 2020     Cleveland, OH           US
# 2  Thu Mar 19 19:56:46 +0000 2020        Corona, CA           US
# 3  Thu Mar 19 19:58:28 +0000 2020   Los Angeles, CA           US
# 4  Thu Mar 19 20:05:01 +0000 2020   Los Angeles, CA           US
#
#          country          coordinates state classification     p_pos     p_neg
# 0  United States   [-82.759, 39.8841]    OH            pos  0.636339  0.363661
# 1  United States  [-81.6937, 41.4996]    OH            neg  0.293557  0.706443
# 2  United States     [-117.58, 33.88]    CA            pos  0.881447  0.118553
# 3  United States  [-118.243, 34.0522]    CA            pos  0.818247  0.181753
# 4  United States  [-118.355, 34.1509]    CA            pos  0.696982  0.303018

# %%
df_3 = pd.concat([df,df_2])

# %%
df_3.drop(columns='index').to_csv('./data/tweets/analyzed_tweets.csv', index=False)

# %%
df = pd.read_csv('./data/tweets/analyzed_tweets.csv')

# %%
df.head()
# Out:
#                                            full_text            id  \
# 0  #statewaterheaters #getitin #corona #keepingpe...  1.240728e+18
# 1  "ain't no humans outside! (corona!)" 😂😂😂🤣 @ Cl...  1.240728e+18
# 2  current weather in Corona: moderate rain, 56°F...  1.240729e+18
# 3  Quarantine 🏓 training ! Adding some kicks 💥. \...  1.240729e+18
# 4  #quarantine #stockpiling #food #sexylatino #la...  1.240731e+18
#
#                              date              city country_code  \
# 0  Thu Mar 19 19:53:17 +0000 2020  Pickerington, OH           US
# 1  Thu Mar 19 19:53:46 +0000 2020     Cleveland, OH           US
# 2  Thu Mar 19 19:56:46 +0000 2020        Corona, CA           US
# 3  Thu Mar 19 19:58:28 +0000 2020   Los Angeles, CA           US
# 4  Thu Mar 19 20:05:01 +0000 2020   Los Angeles, CA           US
#
#          country          coordinates state classification     p_pos     p_neg
# 0  United States   [-82.759, 39.8841]    OH            pos  0.636339  0.363661
# 1  United States  [-81.6937, 41.4996]    OH            neg  0.293557  0.706443
# 2  United States     [-117.58, 33.88]    CA            pos  0.881447  0.118553
# 3  United States  [-118.243, 34.0522]    CA            pos  0.818247  0.181753
# 4  United States  [-118.355, 34.1509]    CA            pos  0.696982  0.303018

# %%
df.to_csv('./data/tweets/analyzed_tweets_for_tableau.csv', index=False, sep = '\n', quotechar = '\t')
